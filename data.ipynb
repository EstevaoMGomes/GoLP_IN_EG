# %%
import pysr

pysr.install(precompile=False)
# Out:
# [ Info: Julia version info
# Julia Version 1.9.3
# Commit bed2cd540a1 (2023-08-24 14:43 UTC)
# Build Info:
#   Official https://julialang.org/ release
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#       Ubuntu 22.04.3 LTS
#   uname: Linux 5.15.0-83-generic #92-Ubuntu SMP Mon Aug 14 09:30:42 UTC 2023 x86_64 x86_64
#   CPU: Intel(R) Core(TM) i7-3820 CPU @ 3.60GHz:
#               speed         user         nice          sys         idle          irq
#        #1  1200 MHz    2224742 s         87 s    1367508 s   21537958 s          0 s
#        #2  1200 MHz    3230476 s         90 s    1938725 s   19977867 s          0 s
#        #3  1200 MHz    2680328 s        158 s    1662582 s   20796626 s          0 s
#        #4  3700 MHz    2162864 s        129 s    1103116 s   21854971 s          0 s
#        #5  1200 MHz    1324633 s        112 s     761988 s   23025923 s          0 s
#        #6  1200 MHz     722235 s         76 s     346143 s   24002216 s          0 s
# ...

# %%
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Introduction
# To start the project first I am going to see to what extent PySR is capable by varying:
# - seed
# - error
# - number of points

# %% [markdown]
# Let´s start with the function
# $$ f(x_0,x_1)=2.1 e^{-(1.4x_0^2+4.3x_0x_1+x_1^2) }$$
# for a given seed and with no error.

# %%
seed = np.array([1,2,3,4])
n = np.array([100,1000,10000,100000])
np.random.seed(seed[0])

def gaussian2D(A,a,b,c,x,y):
    return A*np.exp(-(a*x**2+b*x*y+c*y**2))

i=1
X = 6 * np.random.rand(n[i],2)-3
y = gaussian2D(2.1,1.4,4.3,1,X[:,0],X[:,1])

# %% [markdown]
# Starting our symbolic regression algorithm...

# %%
model = PySRRegressor(
    niterations=20,
    populations=50,
    binary_operators=["+", "-", "*"],
    unary_operators=["exp"],
)
model.fit(X, y)
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1346: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:231: UserWarning: Julia has already started. The new Julia options {'threads': 8} will be ignored.
#   warnings.warn(
# Started!
#
# Expressions evaluated per second: 3.250e+04
# Head worker occupation: 0.8%
# Progress: 62 / 1000 total iterations (6.200%)
# ...
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.004e+04  1.594e+01  y = 1.9434
# 2           4.959e+04  9.040e-03  y = exp(2.1074)
# 3           4.852e+04  2.180e-02  y = (41.003 - x₁)
# 4           4.804e+04  1.002e-02  y = exp(x₁ * x₁)
# 5           4.162e+04  1.433e-01  y = ((-68.58 * x₀) * x₁)
# ...

# %%
model.sympy()
# Out:
# exp(x1*(-1.7550374*x0 + 0.34350285*x1))

# %%
for i in range(4):
    X = 6 * np.random.rand(n[i],2)-3
    y = gaussian2D(2.1,1.4,4.3,1,X[:,0],X[:,1])
    model.fit(X, y)
    model.sympy()
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1886: UserWarning: The discovered expressions are being reset. Please set `warm_start=True` if you wish to continue to start a search where you left off.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1346: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/julia_helpers.py:231: UserWarning: Julia has already started. The new Julia options {'threads': 8} will be ignored.
#   warnings.warn(
# ┌ Warning: You are using multithreading mode, but only one thread is available. Try starting julia with `--threads=auto`.
# └ @ SymbolicRegression ~/.julia/packages/SymbolicRegression/XKtla/src/SymbolicRegression.jl:546
# ...
